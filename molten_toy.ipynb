# %%
2 + 3

# %%
print("hello from Neopyter")

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3]
y = [0, 1, 0, 1]

plt.figure(figsize=(4, 2.5))
plt.plot(x, y, marker="o")
plt.title("Neopyter toy plot")
plt.tight_layout()
plt.show()
